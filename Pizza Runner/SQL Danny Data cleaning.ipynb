# %%
pip install pymysql
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
# Import module
import pymysql
import pandas as pd
import mysql.connector as sql
from sqlalchemy import create_engine

# %%
# create connection
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='ruchita',
                             db='pizza_runner')

# Create cursor
my_cursor = connection.cursor()

# Execute Query
my_cursor.execute("SELECT * from pizza_recipes")

# Fetch the records
result = my_cursor.fetchall()

for i in result:
    print(i)

# Close the connection
connection.close()
# Out:
# (1, '1, 2, 3, 4, 5, 6, 8, 10')
# (2, '4, 6, 7, 9, 11, 12')

# %% [markdown]
# ### Cleaning pizza_recipes

# %%
# create sqlalchemy engine
engine = create_engine("mysql+pymysql://root:ruchita@localhost/pizza_runner"
                       .format(user="localhost",
                               pw="ruchita",
                               db="pizza_runner"))
connection = engine.connect()

# %%
    mydb = sql.connect(host="localhost", database = 'pizza_runner',user="root", passwd="ruchita",use_pure=True)
    query = "Select * from pizza_recipes;"
    clean_pizza_recipes = pd.read_sql(query,mydb)
   # mydb.close() #close the connection
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
clean_pizza_recipes=clean_pizza_recipes.assign(toppings=clean_pizza_recipes.toppings.str.split(",")).explode('toppings')
clean_pizza_recipes
# Out:
#    pizza_id toppings
# 0         1        1
# 0         1        2
# 0         1        3
# 0         1        4
# 0         1        5
# 0         1        6
# 0         1        8
# 0         1       10
# 1         2        4
# 1         2        6
# 1         2        7
# 1         2        9
# 1         2       11
# 1         2       12

# %%
clean_pizza_recipes = clean_pizza_recipes.set_index('pizza_id')
clean_pizza_recipes
# Out:
#          toppings
# pizza_id
# 1               1
# 1               2
# 1               3
# 1               4
# 1               5
# 1               6
# 1               8
# 1              10
# 2               4
# 2               6
# 2               7
# 2               9
# 2              11
# 2              12

# %%
clean_pizza_recipes['toppings']= clean_pizza_recipes.toppings.str.strip()
clean_pizza_recipes
# Out:
#          toppings
# pizza_id
# 1               1
# 1               2
# 1               3
# 1               4
# 1               5
# 1               6
# 1               8
# 1              10
# 2               4
# 2               6
# 2               7
# 2               9
# 2              11
# 2              12

# %%
clean_pizza_recipes.to_sql('clean_pizza_recipes', con = engine, if_exists='replace')
# Out:
# 14

# %% [markdown]
# ### Cleaning customer_orders

# %%
query2 = "select * from clean_customer_orders"
clean_customer_orders = pd.read_sql(query2, mydb)
clean_customer_orders
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#     order_id  customer_id  pizza_id exclusions extras          order_time
# 0          1          101         1       None   None 2020-01-01 18:05:02
# 1          2          101         1       None   None 2020-01-01 19:00:52
# 2          3          102         1       None   None 2020-01-02 23:51:23
# 3          3          102         2       None   None 2020-01-02 23:51:23
# 4          4          103         1          4   None 2020-01-04 13:23:46
# 5          4          103         1          4   None 2020-01-04 13:23:46
# 6          4          103         2          4   None 2020-01-04 13:23:46
# 7          5          104         1       None      1 2020-01-08 21:00:29
# ...

# %% [markdown]
# clean_customer_orders = clean_customer_orders.assign(exclusions=clean_customer_orders.exclusions.str.split(",")).explode('exclusions')
# clean_customer_orders

# %%
clean_customer_orders = clean_customer_orders.assign(extras=clean_customer_orders.extras.str.split(",")).explode('extras')
clean_customer_orders
# Out:
#     order_id  customer_id  pizza_id exclusions extras          order_time
# 0          1          101         1       None   None 2020-01-01 18:05:02
# 1          2          101         1       None   None 2020-01-01 19:00:52
# 2          3          102         1       None   None 2020-01-02 23:51:23
# 3          3          102         2       None   None 2020-01-02 23:51:23
# 4          4          103         1          4   None 2020-01-04 13:23:46
# 5          4          103         1          4   None 2020-01-04 13:23:46
# 6          4          103         2          4   None 2020-01-04 13:23:46
# 7          5          104         1       None      1 2020-01-08 21:00:29
# 8          6          101         2       None   None 2020-01-08 21:03:13
# 9          7          105         2       None      1 2020-01-08 21:20:29
# 10         8          102         1       None   None 2020-01-09 23:54:33
# 11         9          103         1          4      1 2020-01-10 11:22:59
# ...

# %%
# clean_customer_orders.to_sql('clean_customer_orders', con = engine, if_exists='replace')

# %%
clean_customer_orders = clean_customer_orders.set_index('order_id')
clean_customer_orders
# Out:
#           customer_id  pizza_id exclusions extras          order_time
# order_id
# 1                 101         1       None   None 2020-01-01 18:05:02
# 2                 101         1       None   None 2020-01-01 19:00:52
# 3                 102         1       None   None 2020-01-02 23:51:23
# 3                 102         2       None   None 2020-01-02 23:51:23
# 4                 103         1          4   None 2020-01-04 13:23:46
# 4                 103         1          4   None 2020-01-04 13:23:46
# 4                 103         2          4   None 2020-01-04 13:23:46
# 5                 104         1       None      1 2020-01-08 21:00:29
# 6                 101         2       None   None 2020-01-08 21:03:13
# 7                 105         2       None      1 2020-01-08 21:20:29
# 8                 102         1       None   None 2020-01-09 23:54:33
# 9                 103         1          4      1 2020-01-10 11:22:59
# ...

# %%
clean_customer_orders['extras']= clean_customer_orders.extras.str.strip()
clean_customer_orders['exclusions']= clean_customer_orders.exclusions.str.strip()

clean_customer_orders
# Out:
#           customer_id  pizza_id exclusions extras          order_time
# order_id
# 1                 101         1       None   None 2020-01-01 18:05:02
# 2                 101         1       None   None 2020-01-01 19:00:52
# 3                 102         1       None   None 2020-01-02 23:51:23
# 3                 102         2       None   None 2020-01-02 23:51:23
# 4                 103         1          4   None 2020-01-04 13:23:46
# 4                 103         1          4   None 2020-01-04 13:23:46
# 4                 103         2          4   None 2020-01-04 13:23:46
# 5                 104         1       None      1 2020-01-08 21:00:29
# 6                 101         2       None   None 2020-01-08 21:03:13
# 7                 105         2       None      1 2020-01-08 21:20:29
# 8                 102         1       None   None 2020-01-09 23:54:33
# 9                 103         1          4      1 2020-01-10 11:22:59
# ...

# %%
clean_customer_orders.to_sql('clean_cust_orders', con = engine, if_exists='replace')
# Out:
# 36

# %% [markdown]
# ### setting index pizza_recipes
